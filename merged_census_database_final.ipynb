# %%
# %matplotlib notebook

# %%
#import Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import csv

# %%
#read files to be merged
data_file2019 = "Resources/census2019_data_cleaned.csv"
data_file2018 = "Resources/census2018_data_cleaned.csv"
data_file2017 = "Resources/census2017_data_cleaned.csv"
data_file2016 = "Resources/census2016_data_cleaned.csv"
data_file2015 = "Resources/census2015_data_cleaned.csv"
data_file2014 = "Resources/census2014_data_cleaned.csv"
data_file2013 = "Resources/census2013_data_cleaned.csv"
data_file2012 = "Resources/census2012_data_cleaned.csv"
data_file2011 = "Resources/census2011_data_cleaned.csv"

census2019_df = pd.read_csv(data_file2019)
census2018_df = pd.read_csv(data_file2018)
census2017_df = pd.read_csv(data_file2017)
census2016_df = pd.read_csv(data_file2016)
census2015_df = pd.read_csv(data_file2015)
census2014_df = pd.read_csv(data_file2014)
census2013_df = pd.read_csv(data_file2013)
census2012_df = pd.read_csv(data_file2012)
census2011_df = pd.read_csv(data_file2011)

# %%
census2018_df.head()
# Out:
#           Name  Household Income  Per Capita Income  Population  Median Age  \
# 0  ZCTA5 01001             62144              35135       17621        46.1
# 1  ZCTA5 01002             55858              29499       30066        23.4
# 2  ZCTA5 01003              2499               4590       11238        20.0
# 3  ZCTA5 01005             68278              35190        4991        48.1
# 4  ZCTA5 01007             93300              42021       14967        44.0
#
#    Median Rent  Average Year Home Built  Median Mortgage Cost state  Zipcode
# 0          921                     1967                  1556    MA     1001
# 1         1232                     1973                  2248    MA     1002
# 2            0                     1972                     0    MA     1003
# 3          819                     1968                  1597    MA     1005
# 4          874                     1984                  1832    MA     1007

# %%
census2019_df = census2019_df.rename(columns = {"Household Income": "2019 Household Income",
                                               "Per Capita Income": "2019 Per Capita Income",
                                               "Population": "2019 Population",
                                               "Median Age": "2019 Median Age",
                                               "Median Rent": "2019 Median Rent",
                                               "Average Year Home Built": "2019 Avg Year Home Built",
                                               "Median Mortgage Cost": "2019 Median Mortgage Cost",
                                               "state": "2019 state"})
census2019_df.head()
# Out:
#           Name  2019 Household Income  2019 Per Capita Income  \
# 0  ZCTA5 01001                  63949                   36540
# 1  ZCTA5 01002                  61159                   30847
# 2  ZCTA5 01003                   2499                    4378
# 3  ZCTA5 01005                  67302                   37464
# 4  ZCTA5 01007                  91191                   41753
#
#    2019 Population  2019 Median Age  2019 Median Rent  \
# 0            17312             46.1              1025
# 1            30014             23.4              1280
# 2            11357             19.9                 0
# 3             5128             48.1               831
# 4            15005             42.3               909
#
#    2019 Avg Year Home Built  2019 Median Mortgage Cost 2019 state  Zipcode
# 0                      1968                       1506         MA     1001
# 1                      1973                       2330         MA     1002
# ...

# %%
census2018_df = census2018_df.rename(columns = {"Household Income": "2018 Household Income",
                                               "Per Capita Income": "2018 Per Capita Income",
                                               "Population": "2018 Population",
                                               "Median Age": "2018 Median Age",
                                               "Median Rent": "2018 Median Rent",
                                               "Average Year Home Built": "2018 Avg Year Home Built",
                                                "Median Mortgage Cost": "2018 Median Mortgage Cost",
                                               "state": "2018 state"})

census2017_df = census2017_df.rename(columns = {"Household Income": "2017 Household Income",
                                               "Per Capita Income": "2017 Per Capita Income",
                                               "Population": "2017 Population",
                                               "Median Age": "2017 Median Age",
                                               "Median Rent": "2017 Median Rent",
                                               "Average Year Home Built": "2017 Avg Year Home Built",
                                                "Median Mortgage Cost": "2017 Median Mortgage Cost",
                                               "state": "2017 state"})

# %%
census2016_df = census2016_df.rename(columns = {"Household Income": "2016 Household Income",
                                               "Per Capita Income": "2016 Per Capita Income",
                                               "Population": "2016 Population",
                                               "Median Age": "2016 Median Age",
                                               "Median Rent": "2016 Median Rent",
                                               "Average Year Home Built": "2016 Avg Year Home Built",
                                                "Median Mortgage Cost": "2016 Median Mortgage Cost",
                                               "state": "2016 state"})

# %%
census2015_df = census2015_df.rename(columns = {"Household Income": "2015 Household Income",
                                               "Per Capita Income": "2015 Per Capita Income",
                                               "Population": "2015 Population",
                                               "Median Age": "2015 Median Age",
                                               "Median Rent": "2015 Median Rent",
                                               "Average Year Home Built": "2015 Avg Year Home Built",
                                                "Median Mortgage Cost": "2015 Median Mortgage Cost",
                                               "state": "2015 state"})

# %%
census2014_df = census2014_df.rename(columns = {"Household Income": "2014 Household Income",
                                               "Per Capita Income": "2014 Per Capita Income",
                                               "Population": "2014 Population",
                                               "Median Age": "2014 Median Age",
                                               "Median Rent": "2014 Median Rent",
                                               "Average Year Home Built": "2014 Avg Year Home Built",
                                                "Median Mortgage Cost": "2014 Median Mortgage Cost",
                                               "state": "2014 state"})

census2013_df = census2013_df.rename(columns = {"Household Income": "2013 Household Income",
                                               "Per Capita Income": "2013 Per Capita Income",
                                               "Population": "2013 Population",
                                               "Median Age": "2013 Median Age",
                                               "Median Rent": "2013 Median Rent",
                                               "Average Year Home Built": "2013 Avg Year Home Built",
                                                "Median Mortgage Cost": "2013 Median Mortgage Cost",
                                               "state": "2013 state"})

# %%
census2012_df = census2012_df.rename(columns = {"Household Income": "2012 Household Income",
                                               "Per Capita Income": "2012 Per Capita Income",
                                               "Population": "2012 Population",
                                               "Median Age": "2012 Median Age",
                                               "Median Rent": "2012 Median Rent",
                                               "Average Year Home Built": "2012 Avg Year Home Built",
                                                "Median Mortgage Cost": "2012 Median Mortgage Cost",
                                               "state": "2012 state"})

census2011_df = census2011_df.rename(columns = {"Household Income": "2011 Household Income",
                                               "Per Capita Income": "2011 Per Capita Income",
                                               "Population": "2011 Population",
                                               "Median Age": "2011 Median Age",
                                               "Median Rent": "2011 Median Rent",
                                               "Average Year Home Built": "2011 Avg Year Home Built",
                                                "Median Mortgage Cost": "2011 Median Mortgage Cost",
                                               "state": "2011 state"})

# %%
census2011_df.head()
# Out:
#           Name  2011 Household Income  2011 Per Capita Income  \
# 0  ZCTA5 12852                  50417                   25336
# 1  ZCTA5 12853                  39167                   20647
# 2  ZCTA5 12855                  46458                   22856
# 3  ZCTA5 12856                  46250                   54503
# 4  ZCTA5 12857                  52917                   21907
#
#    2011 Population  2011 Median Age  2011 Median Rent  \
# 0              504             57.0               475
# 1             1406             43.5               405
# 2              203             45.1                99
# 3              117             65.4                 0
# 4              467             48.6               593
#
#    2011 Avg Year Home Built  2011 Median Mortgage Cost 2011 state  Zipcode
# 0                      1962                       1109         NY    12852
# 1                      1965                       1163         NY    12853
# ...

# %%
#merging databases into one overall censuse database for 2011 thru 2019
merged_census_df = pd.merge(census2019_df, census2018_df, on="Name")
merged_census_df
# Out:
#               Name  2019 Household Income  2019 Per Capita Income  \
# 0      ZCTA5 01001                  63949                   36540
# 1      ZCTA5 01002                  61159                   30847
# 2      ZCTA5 01003                   2499                    4378
# 3      ZCTA5 01005                  67302                   37464
# 4      ZCTA5 01007                  91191                   41753
# ...            ...                    ...                     ...
# 30161  ZCTA5 99921                  52188                   31807
# 30162  ZCTA5 99922                  33750                   18258
# 30163  ZCTA5 99925                  62917                   30321
# 30164  ZCTA5 99926                  56188                   22267
# 30165  ZCTA5 99929                  53894                   32286
#
#        2019 Population  2019 Median Age  2019 Median Rent  \
# 0                17312             46.1              1025
# ...

# %%
merge2_census_df = pd.merge(merged_census_df, census2017_df, on="Name")
merge2_census_df.head()
# Out:
#           Name  2019 Household Income  2019 Per Capita Income  \
# 0  ZCTA5 01001                  63949                   36540
# 1  ZCTA5 01002                  61159                   30847
# 2  ZCTA5 01003                   2499                    4378
# 3  ZCTA5 01005                  67302                   37464
# 4  ZCTA5 01007                  91191                   41753
#
#    2019 Population  2019 Median Age  2019 Median Rent  \
# 0            17312             46.1              1025
# 1            30014             23.4              1280
# 2            11357             19.9                 0
# 3             5128             48.1               831
# 4            15005             42.3               909
#
#    2019 Avg Year Home Built  2019 Median Mortgage Cost 2019 state  Zipcode_x  \
# 0                      1968                       1506         MA       1001
# 1                      1973                       2330         MA       1002
# ...

# %%
merge3_census_df = pd.merge(merge2_census_df, census2016_df, on="Name")
merge3_census_df.head()
# Out:
#           Name  2019 Household Income  2019 Per Capita Income  \
# 0  ZCTA5 01001                  63949                   36540
# 1  ZCTA5 01002                  61159                   30847
# 2  ZCTA5 01003                   2499                    4378
# 3  ZCTA5 01005                  67302                   37464
# 4  ZCTA5 01007                  91191                   41753
#
#    2019 Population  2019 Median Age  2019 Median Rent  \
# 0            17312             46.1              1025
# 1            30014             23.4              1280
# 2            11357             19.9                 0
# 3             5128             48.1               831
# 4            15005             42.3               909
#
#    2019 Avg Year Home Built  2019 Median Mortgage Cost 2019 state  Zipcode_x  \
# 0                      1968                       1506         MA       1001
# 1                      1973                       2330         MA       1002
# ...

# %%
merge4_census_df = pd.merge(merge3_census_df, census2015_df, on="Name")
merge4_census_df.head()
# Out:
#           Name  2019 Household Income  2019 Per Capita Income  \
# 0  ZCTA5 01001                  63949                   36540
# 1  ZCTA5 01002                  61159                   30847
# 2  ZCTA5 01003                   2499                    4378
# 3  ZCTA5 01005                  67302                   37464
# 4  ZCTA5 01007                  91191                   41753
#
#    2019 Population  2019 Median Age  2019 Median Rent  \
# 0            17312             46.1              1025
# 1            30014             23.4              1280
# 2            11357             19.9                 0
# 3             5128             48.1               831
# 4            15005             42.3               909
#
#    2019 Avg Year Home Built  2019 Median Mortgage Cost 2019 state  Zipcode_x  \
# 0                      1968                       1506         MA       1001
# 1                      1973                       2330         MA       1002
# ...

# %%
merge5_census_df = pd.merge(merge4_census_df, census2014_df, on="Name")
merge5_census_df.head()
# Out:
#           Name  2019 Household Income  2019 Per Capita Income  \
# 0  ZCTA5 01001                  63949                   36540
# 1  ZCTA5 01002                  61159                   30847
# 2  ZCTA5 01005                  67302                   37464
# 3  ZCTA5 01007                  91191                   41753
# 4  ZCTA5 01008                  76333                   40146
#
#    2019 Population  2019 Median Age  2019 Median Rent  \
# 0            17312             46.1              1025
# 1            30014             23.4              1280
# 2             5128             48.1               831
# 3            15005             42.3               909
# 4             1140             54.0                 0
#
#    2019 Avg Year Home Built  2019 Median Mortgage Cost 2019 state  Zipcode_x  \
# 0                      1968                       1506         MA       1001
# 1                      1973                       2330         MA       1002
# ...

# %%
merge6_census_df = pd.merge(merge5_census_df, census2013_df, on="Name")
merge6_census_df.head()
# Out:
#           Name  2019 Household Income  2019 Per Capita Income  \
# 0  ZCTA5 01001                  63949                   36540
# 1  ZCTA5 01002                  61159                   30847
# 2  ZCTA5 01005                  67302                   37464
# 3  ZCTA5 01007                  91191                   41753
# 4  ZCTA5 01008                  76333                   40146
#
#    2019 Population  2019 Median Age  2019 Median Rent  \
# 0            17312             46.1              1025
# 1            30014             23.4              1280
# 2             5128             48.1               831
# 3            15005             42.3               909
# 4             1140             54.0                 0
#
#    2019 Avg Year Home Built  2019 Median Mortgage Cost 2019 state  Zipcode_x  \
# 0                      1968                       1506         MA       1001
# 1                      1973                       2330         MA       1002
# ...

# %%
merge7_census_df = pd.merge(merge6_census_df, census2012_df, on="Name")
merge7_census_df.head()
# Out:
#           Name  2019 Household Income  2019 Per Capita Income  \
# 0  ZCTA5 01001                  63949                   36540
# 1  ZCTA5 01002                  61159                   30847
# 2  ZCTA5 01005                  67302                   37464
# 3  ZCTA5 01007                  91191                   41753
# 4  ZCTA5 01008                  76333                   40146
#
#    2019 Population  2019 Median Age  2019 Median Rent  \
# 0            17312             46.1              1025
# 1            30014             23.4              1280
# 2             5128             48.1               831
# 3            15005             42.3               909
# 4             1140             54.0                 0
#
#    2019 Avg Year Home Built  2019 Median Mortgage Cost 2019 state  Zipcode_x  \
# 0                      1968                       1506         MA       1001
# 1                      1973                       2330         MA       1002
# ...

# %%
merge8_census_df = pd.merge(merge7_census_df, census2011_df, on="Name")
merge8_census_df.head()
# Out:
#           Name  2019 Household Income  2019 Per Capita Income  \
# 0  ZCTA5 01001                  63949                   36540
# 1  ZCTA5 01002                  61159                   30847
# 2  ZCTA5 01005                  67302                   37464
# 3  ZCTA5 01007                  91191                   41753
# 4  ZCTA5 01008                  76333                   40146
#
#    2019 Population  2019 Median Age  2019 Median Rent  \
# 0            17312             46.1              1025
# 1            30014             23.4              1280
# 2             5128             48.1               831
# 3            15005             42.3               909
# 4             1140             54.0                 0
#
#    2019 Avg Year Home Built  2019 Median Mortgage Cost 2019 state  Zipcode_x  \
# 0                      1968                       1506         MA       1001
# 1                      1973                       2330         MA       1002
# ...

# %%
#creating a dictionary
region = {
    'West': ["AK", "HI", "CA", "NV", "OR", "WA", "ID", "MT", "CO", "WY", "UT", "AZ", "NM"],

    'Midwest': ["ND", "SD", "NE", "KS", "MN", "IA", "MO", "WI", "IL", "MI", "IN", "OH"],

    'South': ["TX", "OK", "AR", "LA", "AL", "MS", "GA", "FL", "KY", "TN", "NC", "SC", "VA", "WV"],

    'Northeast' : ["ME", "NH", "VT", "MA", "CT", "RI", "NY", "PA", "NJ", "MD", "DE", "DC"]
 }

# %%
merge8_census_df['Region'] = ''

# %%
merge8_census_df.loc[(merge8_census_df['2019 state'].isin(region['West'])),'Region'] ='West'
merge8_census_df.loc[(merge8_census_df['2019 state'].isin(region['Midwest'])),'Region']='Midwest'
merge8_census_df.loc[(merge8_census_df['2019 state'].isin(region['South'])),'Region']='South'
merge8_census_df.loc[(merge8_census_df['2019 state'].isin(region['Northeast'])),'Region']='Northeast'
merge8_census_df
# Out:
#               Name  2019 Household Income  2019 Per Capita Income  \
# 0      ZCTA5 01001                  63949                   36540
# 1      ZCTA5 01002                  61159                   30847
# 2      ZCTA5 01005                  67302                   37464
# 3      ZCTA5 01007                  91191                   41753
# 4      ZCTA5 01008                  76333                   40146
# ...            ...                    ...                     ...
# 29521  ZCTA5 99921                  52188                   31807
# 29522  ZCTA5 99922                  33750                   18258
# 29523  ZCTA5 99925                  62917                   30321
# 29524  ZCTA5 99926                  56188                   22267
# 29525  ZCTA5 99929                  53894                   32286
#
#        2019 Population  2019 Median Age  2019 Median Rent  \
# 0                17312             46.1              1025
# ...

# %%
merge8_census_df.dtypes
# Out:
# Name                          object
# 2019 Household Income          int64
# 2019 Per Capita Income         int64
# 2019 Population                int64
# 2019 Median Age              float64
#                               ...
# 2011 Avg Year Home Built       int64
# 2011 Median Mortgage Cost      int64
# 2011 state                    object
# Zipcode                        int64
# Region                        object
# Length: 83, dtype: object

# %%
#running means of Household Income, Rent rate and Mortgage per Region

# %%
#grouped_regions_df = merge8_census_df.groupby(["Region"])["2019 Household Income","2018 Household Income", "2017 Household Income", "2016 Household Income","2015 Household Income", "2014 Household Income", "2013 Household Income","2012 Household Income","2011 Household Income"]
#grouped_regions_df.mean()
grouped_regions_df = merge8_census_df.groupby(['Region'])
grouped_regions_df["2018 Household Income"].mean()
# Out:
# Region
# Midwest      57920.122464
# Northeast    71948.318457
# South        51005.529964
# West         62883.869736
# Name: 2018 Household Income, dtype: float64

# %%
grouped_regions_df = merge8_census_df.groupby(['Region'])
grouped_regions_df["2018 Household Income"].mean()
# Out:
# Region
# Midwest      57920.122464
# Northeast    71948.318457
# South        51005.529964
# West         62883.869736
# Name: 2018 Household Income, dtype: float64

# %%
grouped_regions_df = merge8_census_df.groupby(['Region'])
grouped_regions_df["2017 Household Income"].mean()
# Out:
# Region
# Midwest      55856.556908
# Northeast    69215.765746
# South        49136.666667
# West         60160.470479
# Name: 2017 Household Income, dtype: float64

# %%
grouped_regions_df = merge8_census_df.groupby(['Region'])
grouped_regions_df["2016 Household Income"].mean()
# Out:
# Region
# Midwest      53881.299060
# Northeast    66801.393398
# South        47403.315526
# West         57540.044178
# Name: 2016 Household Income, dtype: float64

# %%
grouped_regions_df = merge8_census_df.groupby(['Region'])
grouped_regions_df["2015 Household Income"].mean()
# Out:
# Region
# Midwest      52605.617657
# Northeast    65300.519641
# South        46408.535026
# West         56186.132472
# Name: 2015 Household Income, dtype: float64

# %%
grouped_regions_df = merge8_census_df.groupby(['Region'])
grouped_regions_df["2014 Household Income"].mean()
# Out:
# Region
# Midwest      51893.376682
# Northeast    64582.625800
# South        45932.227554
# West         55533.246284
# Name: 2014 Household Income, dtype: float64

# %%
grouped_regions_df = merge8_census_df.groupby(['Region'])
grouped_regions_df["2013 Household Income"].mean()
# Out:
# Region
# Midwest      51035.335575
# Northeast    63851.761199
# South        45510.879612
# West         54912.022915
# Name: 2013 Household Income, dtype: float64

# %%
grouped_regions_df = merge8_census_df.groupby(['Region'])
grouped_regions_df["2012 Household Income"].mean()
# Out:
# Region
# Midwest      50735.743861
# Northeast    63450.882452
# South        45331.523886
# West         54864.129851
# Name: 2012 Household Income, dtype: float64

# %%
grouped_regions_df = merge8_census_df.groupby(['Region'])
grouped_regions_df["2011 Household Income"].mean()
# Out:
# Region
# Midwest      50244.629831
# Northeast    62777.812732
# South        45067.566752
# West         54819.177126
# Name: 2011 Household Income, dtype: float64

# %%
grouped_regions_df = merge8_census_df.groupby(['Region'])
grouped_regions_df['2019 Median Rent'].mean()
# Out:
# Region
# Midwest      525.770019
# Northeast    848.689121
# South        589.667093
# West         887.375310
# Name: 2019 Median Rent, dtype: float64

# %%
grouped_regions_df = merge8_census_df.groupby(['Region'])
grouped_regions_df['2018 Median Rent'].mean()
# Out:
# Region
# Midwest      512.435832
# Northeast    828.914786
# South        572.552463
# West         855.430429
# Name: 2018 Median Rent, dtype: float64

# %%
grouped_regions_df = merge8_census_df.groupby(['Region'])
grouped_regions_df['2017 Median Rent'].mean()
# Out:
# Region
# Midwest      497.809631
# Northeast    803.001852
# South        552.986031
# West         820.857762
# Name: 2017 Median Rent, dtype: float64

# %%
grouped_regions_df = merge8_census_df.groupby(['Region'])
grouped_regions_df['2016 Median Rent'].mean()
# Out:
# Region
# Midwest      487.528828
# Northeast    783.335466
# South        537.873534
# West         793.296449
# Name: 2016 Median Rent, dtype: float64

# %%
grouped_regions_df = merge8_census_df.groupby(['Region'])
grouped_regions_df['2015 Median Rent'].mean()
# Out:
# Region
# Midwest      485.914864
# Northeast    779.894323
# South        534.360004
# West         788.800042
# Name: 2015 Median Rent, dtype: float64

# %%
grouped_regions_df = merge8_census_df.groupby(['Region'])
grouped_regions_df['2014 Median Rent'].mean()
# Out:
# Region
# Midwest      475.560325
# Northeast    759.406871
# South        520.310514
# West         765.196532
# Name: 2014 Median Rent, dtype: float64

# %%
grouped_regions_df = merge8_census_df.groupby(['Region'])
grouped_regions_df['2013 Median Rent'].mean()
# Out:
# Region
# Midwest      462.270660
# Northeast    741.737959
# South        507.092664
# West         751.064822
# Name: 2013 Median Rent, dtype: float64

# %%
grouped_regions_df = merge8_census_df.groupby(['Region'])
grouped_regions_df['2012 Median Rent'].mean()
# Out:
# Region
# Midwest      464.611253
# Northeast    750.144156
# South        506.705481
# West         750.843518
# Name: 2012 Median Rent, dtype: float64

# %%
grouped_regions_df = merge8_census_df.groupby(['Region'])
grouped_regions_df['2011 Median Rent'].mean()
# Out:
# Region
# Midwest      451.104207
# Northeast    726.327383
# South        492.018128
# West         729.596408
# Name: 2011 Median Rent, dtype: float64

# %%
grouped_regions_df = merge8_census_df.groupby(['Region'])
grouped_regions_df['2019 Median Mortgage Cost'].mean()
# Out:
# Region
# Midwest      1191.020713
# Northeast    1760.319299
# South        1201.080934
# West         1651.416598
# Name: 2019 Median Mortgage Cost, dtype: float64

# %%
grouped_regions_df = merge8_census_df.groupby(['Region'])
grouped_regions_df['2018 Median Mortgage Cost'].mean()
# Out:
# Region
# Midwest      1173.640615
# Northeast    1737.293365
# South        1177.837599
# West         1603.103014
# Name: 2018 Median Mortgage Cost, dtype: float64

# %%
grouped_regions_df = merge8_census_df.groupby(['Region'])
grouped_regions_df['2017 Median Mortgage Cost'].mean()
# Out:
# Region
# Midwest      1150.035981
# Northeast    1702.169754
# South        1150.309661
# West         1559.130264
# Name: 2017 Median Mortgage Cost, dtype: float64

# %%
grouped_regions_df = merge8_census_df.groupby(['Region'])
grouped_regions_df['2016 Median Mortgage Cost'].mean()
# Out:
# Region
# Midwest      1137.922699
# Northeast    1681.941900
# South        1131.852527
# West         1530.882742
# Name: 2016 Median Mortgage Cost, dtype: float64

# %%
grouped_regions_df = merge8_census_df.groupby(['Region'])
grouped_regions_df['2015 Median Mortgage Cost'].mean()
# Out:
# Region
# Midwest      1148.859326
# Northeast    1696.981501
# South        1141.416930
# West         1556.463441
# Name: 2015 Median Mortgage Cost, dtype: float64

# %%
grouped_regions_df = merge8_census_df.groupby(['Region'])
grouped_regions_df['2014 Median Mortgage Cost'].mean()
# Out:
# Region
# Midwest      1159.927290
# Northeast    1709.911250
# South        1150.064513
# West         1569.050991
# Name: 2014 Median Mortgage Cost, dtype: float64

# %%
grouped_regions_df = merge8_census_df.groupby(['Region'])
grouped_regions_df['2013 Median Mortgage Cost'].mean()
# Out:
# Region
# Midwest      1161.131753
# Northeast    1716.034523
# South        1151.555342
# West         1585.743807
# Name: 2013 Median Mortgage Cost, dtype: float64

# %%
grouped_regions_df = merge8_census_df.groupby(['Region'])
grouped_regions_df['2012 Median Mortgage Cost'].mean()
# Out:
# Region
# Midwest      1172.937754
# Northeast    1730.910744
# South        1161.354553
# West         1623.182907
# Name: 2012 Median Mortgage Cost, dtype: float64

# %%
grouped_regions_df = merge8_census_df.groupby(['Region'])
grouped_regions_df['2011 Median Mortgage Cost'].mean()
# Out:
# Region
# Midwest      1167.026799
# Northeast    1717.567531
# South        1154.365856
# West         1631.654005
# Name: 2011 Median Mortgage Cost, dtype: float64

# %%
# Creating x and y axis lists for rent
time = np.arange( 2011, 2020, 1)
northeast_rent =[726.33, 750.14, 741.74, 759.41, 779.89, 783.34, 803.00, 828.91, 848.69]
south_rent = [499.46, 513.85, 514.26, 527.82, 540.90, 544.84, 559.58, 579.77, 597.15]
midwest_rent = [442.90, 456.65, 454.04, 467.20, 478.32, 479.62, 490.00, 504.17, 517.43]
west_rent = [729.60, 750.84, 751.06, 765.20, 788.80, 793.30, 820.86, 855.43, 887.38]

# %%
#plotting the chart and applying some styling
plt.figure(0)
plt.plot(time, northeast_rent, color="blue", label="Northeast")
plt.plot(time, south_rent, color="red", label="South")
plt.plot(time, midwest_rent, color="green", label="Midwest")
plt.plot(time, west_rent, color="orange", label="West")
plt.xlabel("Years")
plt.ylabel("Monthly Rent (USD)")
plt.title("Rent in the United States from 2011 - 2019")
plt.legend(loc="best")
plt.savefig('.\\output\\monthlyrent')
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
# Creating x and y axis lists for mortgage
national_mortgage = [1349.95, 1355.34, 1339.35, 1334.52, 1322.84, 1309.87, 1328.28, 1385.79, 1384.24]
northeast_mortgage = [1717.57, 1730.91, 1716.03, 1709.91, 1696.98, 1681.94, 1702.17, 1737.29, 1760.32]
south_mortgage = [1171.92, 1177.15, 1165.73, 1161.90, 1151.87, 1141.41, 1159.19, 1185.77, 1208.78]
midwest_mortgage = [1157.07, 1164.56, 1154.48, 1155.41, 1145.81, 1135.22, 1147.77, 1171.68, 1189.54]
west_mortgage = [1631.65, 1623.18, 1585.74, 1596.05, 1556.46, 1530.88, 1559.13, 1603.10, 1651.42]

# %%
plt.figure(1)
plt.plot(time, national_mortgage, color="black", label="National")
plt.plot(time, northeast_mortgage, color="blue", label="Northeast")
plt.plot(time, south_mortgage, color="red", label="South")
plt.plot(time, midwest_mortgage, color="green", label="Midwest")
plt.plot(time, west_mortgage, color="orange", label="West")
plt.xlabel("Years")
plt.ylabel("Monthly Mortgage (USD)")
plt.title("Monthly Mortgage rates in the United States from 2011 - 2019")
plt.legend(loc="center left")
plt.savefig('.\\output\\monthlymortgage')
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
# Creating x and y axis lists for household income
national_income = [51871.35, 52253.72, 52494.19, 53149.11, 53785.27, 55022.39, 57114.97, 59359.49, 61641.76 ]
northeast_income = [62777.81, 63450.88, 63851.76, 64582.63, 65300.52, 66801.39, 69215.77, 71948.32, 74515.45]
south_income = [45746.13, 45986.52, 46145.61, 46593.13, 47073.74, 48086.57, 49869.14, 51811.06, 53919.77]
midwest_income = [50451.61, 50996.78, 51327.68, 52208.87,52943.44, 54244.57, 56204.21, 58223.91, 60266.74]
west_income = [54819.18, 54864.13, 54912.02, 55533.25, 56186.13, 57540.04, 60160.47, 62883.87, 65664.62]

# %%
plt.figure(2)
national_income, = plt.plot(time, national_income, color="black", label="National")
northeast_income, = plt.plot(time, northeast_income, color="blue", label="Northeast")
south_income, = plt.plot(time, south_income, color="red", label="South")
midwest_income, = plt.plot(time, midwest_income, color="green", label="Midwest")
west_mortgage, = plt.plot(time, west_income, color="orange", label="West")
plt.xlabel("Years")
plt.ylabel("Annual Household Income (USD)")
plt.title("Annual Household Income in the United States from 2011 - 2019")
plt.legend(loc="best")
plt.savefig('.\\output\\annualincome')
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
#saved merged census files 
merge8_census_df.to_csv("revisedfinal2_merge_census_database.csv", encoding="utf-8", index=False)
